# %% [markdown]
# # Clustering with DBSCAN

# %% [markdown]
# In this notebook we will come back to our penguins data and apply the DBSCAN clustering algorithm.
#
# At the end of this notebook you should:
# * know how to use the sklearn implementations of `DBSCAN`
# * know which steps are necessary to perform clustering with `DBSCAN`

# %%
# Import all necessary libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Steps to follow
# **Hint:** You can use the k-means-in-python notebook as guide for this exercise.

# %%
# read in the data
df = pd.read_csv('data/penguins_cluster.csv')
df
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 3    Adelie            36.7           19.3              193.0       3450.0
# 4    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 301  Gentoo            47.2           13.7              214.0       4925.0
# 302  Gentoo            46.8           14.3              215.0       4850.0
# 303  Gentoo            50.4           15.7              222.0       5750.0
# 304  Gentoo            45.2           14.8              212.0       5200.0
# 305  Gentoo            49.9           16.1              213.0       5400.0
#
# [306 rows x 5 columns]

# %%
# We again are going work with the numerical data. Filter out the species column, name the dataset df_num.
df_num = df[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]
df_num.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 3            36.7           19.3              193.0       3450.0
# 4            39.3           20.6              190.0       3650.0

# %%
# Set up the scaler object to standardize the data using StandardScaler()
# Call the scaled DataFrame "df_num_scaled"
scaler = StandardScaler()
scaler.fit(df_num)
df_num_scaled = scaler.transform(df_num)
df_num_scaled
# Out:
# array([[-0.88298091,  0.87013517, -1.42234005, -0.56640027],
#        [-0.81240701,  0.19971144, -1.07448514, -0.5058629 ],
#        [-0.67125922,  0.50913778, -0.44834632, -1.17177393],
#        ...,
#        [ 1.11073163, -0.67699651,  1.43007016,  1.85509441],
#        [ 0.19327099, -1.14113601,  0.73436035,  1.18918337],
#        [ 1.02251426, -0.47071228,  0.80393133,  1.43133284]],
#       shape=(306, 4))

# %% [markdown]
# #### Determining DBSCAN hyperparameters
# What do we need as arguments for DBSCAN(eps=?, min_samples=?)

# %% [markdown]
# **min_samples**
# The min_samples might be iteratively refined based on experimental results and insights gained from evaluating clustering performance metrics. We start with min_samples = 4 (as the count of our features).
#
# **eps**
# The elbow plot method can be adapted for DBSCAN to help determine an appropriate value for the eps (epsilon) parameter. Here's a step-by-step description of how to use this method:
#
# 1. Compute the k-distances:
# For each data point, compute the distance to its k-th nearest neighbor, where k is typically set to the value of min_samples.
# 2. Sort the distances:
# Sort these k-distances in ascending order.
# 3. Plot the distances:
# Create a plot of these sorted k-distances against their indices.
# 4. Identify the "elbow" point:
# Look for a point in the plot where the slope of the curve changes sharply, resembling an "elbow". This point is often considered a good candidate for eps.
# The elbow point represents the distance at which the density of points changes significantly, helping to distinguish between points that are close enough to be considered part of the same cluster and points that are further apart.

# %%
from sklearn.neighbors import NearestNeighbors

X = df_num_scaled

# # Fit nearest neighbors
# Initializes a NearestNeighbors object with the parameter n_neighbors set to 4. 
# This means that for each point in your dataset X, it will find the 4 nearest neighbors.
nbrs = NearestNeighbors(n_neighbors=4).fit(X)

# 'distances': Array where each element distances[i] contains the distances to the 4 nearest neighbors of point X[i].
# '_': Array of indices of the 4 nearest neighbors of each point X[i]. Not used in the following code.
distances, _ = nbrs.kneighbors(X)

# %%
# Sort distances and plot
distances = np.sort(distances[:, 1], axis=0)  # Sort by distance to the second nearest neighbor

# Plot the elbow
plt.figure(figsize=(10, 6))
plt.plot(distances)
plt.xlabel('Points sorted by distance')
plt.ylabel('Distance to nearest neighbor')
plt.title('Elbow Plot for DBSCAN hyperparameter epsilon')
plt.grid(True)
plt.show()

# %% [markdown]
# The sorted distances are plotted, with the x-axis representing the sorted data points and the y-axis representing the k-distances.
# Interpreting the Elbow Plot:
# The "elbow" point in the plot, where the curve bends and the slope changes sharply, indicates a suitable value for eps. This point marks a transition from points that are close together (and likely in the same cluster) to points that are further apart.
#
# We might choose eps=0.65, based on our findings.
#
# By using the elbow plot method, you can visually determine an appropriate value for eps that helps DBSCAN distinguish between dense regions (clusters) and sparser regions (noise) in your dataset.

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.65
                ,min_samples=5)
dbscan.fit(df_num_scaled)
# Out:
# DBSCAN(eps=0.65)

# %%
# Write the clusters (dbscan.labels_) to the dataframe as a new column "dbscan_clusters".
df['dbscan_clusters'] = dbscan.labels_

#print dataframe
df.head()
# Out:
#   species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Adelie            39.1           18.7              181.0       3750.0
# 1  Adelie            39.5           17.4              186.0       3800.0
# 2  Adelie            40.3           18.0              195.0       3250.0
# 3  Adelie            36.7           19.3              193.0       3450.0
# 4  Adelie            39.3           20.6              190.0       3650.0
#
#    dbscan_clusters
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
# Set up scatterplot with 
# x=df['bill_length_mm']
# y=df['bill_depth_mm'] 
# and the color of points based on cluster labels

# %%
sns.scatterplot(data= df,x="bill_length_mm", y= "bill_depth_mm")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data= df, x="bill_length_mm", y= "bill_depth_mm", hue="dbscan_clusters")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# **Congratulations**,
# you have clustered our penguins with DBSCAN.
#
# "Noise" has the label "-1" - these ar apparently the penguins that don't want to be pigeonholed!

# %% [markdown]
# And if you want to dive deeper into the subject matter, listen carefully:
# https://www.youtube.com/watch?v=GflW9_t7LZk

# %%
adelie = df.loc[df['species'] == 'Adelie']
adelie['dbscan_clusters'].unique()  #which label got Adelie?
# Out:
# array([ 0, -1])

# %%
gentoo = df.loc[df['species'] == 'Gentoo']
gentoo['dbscan_clusters'].unique()
# Out:
# array([ 2, -1])

# %%
chinstrap = df.loc[df['species'] == 'Chinstrap']
chinstrap['dbscan_clusters'].unique()
# Out:
# array([ 1, -1])
