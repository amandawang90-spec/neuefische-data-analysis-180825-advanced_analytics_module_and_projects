# %% [markdown]
# ## Is the conversion rate better for night shifts?

# %%
import pandas as pd
from statsmodels.stats.proportion import proportions_ztest

tips = pd.read_csv('data/tips_success.csv')

# %%
tips
# Out:
#            date version  conversion
# 0    2023-04-12   night           0
# 1    2023-03-30   night           0
# 2    2023-04-12     day           0
# 3    2023-03-28     day           0
# 4    2023-04-13   night           0
# ..          ...     ...         ...
# 663  2023-04-04     day           0
# 664  2023-03-30   night           0
# 665  2023-03-30     day           0
# 666  2023-04-01     day           0
# 667  2023-04-12   night           0
#
# [668 rows x 3 columns]

# %%
tips.conversion.value_counts()
# Out:
# conversion
# 0    583
# 1     85
# Name: count, dtype: int64

# %%
for i in range(len(tips)):
    if tips.loc[i, 'conversion'] !=0:
        print(f'index:{i},conversion: {tips.loc[i, 'conversion']})')
    i=i+1
# Out:
# index:18,conversion: 1)
# index:26,conversion: 1)
# index:43,conversion: 1)
# index:56,conversion: 1)
# index:63,conversion: 1)
# index:75,conversion: 1)
# index:78,conversion: 1)
# index:79,conversion: 1)
# index:87,conversion: 1)
# index:100,conversion: 1)
# index:104,conversion: 1)
# index:105,conversion: 1)
# index:106,conversion: 1)
# index:113,conversion: 1)
# index:116,conversion: 1)
# index:118,conversion: 1)
# index:123,conversion: 1)
# index:134,conversion: 1)
# index:162,conversion: 1)
# index:165,conversion: 1)
# index:168,conversion: 1)
# index:172,conversion: 1)
# index:177,conversion: 1)
# index:179,conversion: 1)
# index:182,conversion: 1)
# index:186,conversion: 1)
# index:193,conversion: 1)
# index:195,conversion: 1)
# index:196,conversion: 1)
# index:214,conversion: 1)
# index:221,conversion: 1)
# index:229,conversion: 1)
# index:232,conversion: 1)
# index:239,conversion: 1)
# index:247,conversion: 1)
# index:256,conversion: 1)
# index:262,conversion: 1)
# index:267,conversion: 1)
# index:272,conversion: 1)
# index:292,conversion: 1)
# index:294,conversion: 1)
# index:296,conversion: 1)
# index:304,conversion: 1)
# index:321,conversion: 1)
# index:328,conversion: 1)
# index:333,conversion: 1)
# index:339,conversion: 1)
# index:348,conversion: 1)
# index:355,conversion: 1)
# index:363,conversion: 1)
# index:375,conversion: 1)
# index:394,conversion: 1)
# index:400,conversion: 1)
# index:402,conversion: 1)
# index:407,conversion: 1)
# index:414,conversion: 1)
# index:418,conversion: 1)
# index:420,conversion: 1)
# index:423,conversion: 1)
# index:427,conversion: 1)
# index:430,conversion: 1)
# index:454,conversion: 1)
# index:458,conversion: 1)
# index:463,conversion: 1)
# index:490,conversion: 1)
# index:491,conversion: 1)
# index:500,conversion: 1)
# index:527,conversion: 1)
# index:541,conversion: 1)
# index:542,conversion: 1)
# index:545,conversion: 1)
# index:549,conversion: 1)
# index:551,conversion: 1)
# index:561,conversion: 1)
# index:566,conversion: 1)
# index:568,conversion: 1)
# index:569,conversion: 1)
# index:571,conversion: 1)
# index:577,conversion: 1)
# index:590,conversion: 1)
# index:595,conversion: 1)
# index:611,conversion: 1)
# index:618,conversion: 1)
# index:645,conversion: 1)
# index:658,conversion: 1)

# %%
tips['version'].value_counts()
# Out:
# version
# day      335
# night    333
# Name: count, dtype: int64

# %%
tips['conversion'].value_counts()
# Out:
# conversion
# 0    583
# 1     85
# Name: count, dtype: int64

# %%
tips_night = tips[tips['version'] == 'night']
tips_day = tips[tips['version'] == 'day']

n_night = len(tips_night)
n_day = len(tips_day)
successes = [tips_night.conversion.sum(), tips_day.conversion.sum()]
nobs = [n_night, n_day]

z_stat, pval = proportions_ztest(successes, nobs=nobs)

print(f'conversion rate for day shift: {tips_day.conversion.sum()/n_day}')
print(f'conversion rate for night shift: {tips_night.conversion.sum()/n_night}')
print(f'z statistic: {z_stat:.2f}')
print(f'p-value: {pval:.3f}')
# Out:
# conversion rate for day shift: 0.0955223880597015
# conversion rate for night shift: 0.15915915915915915
# z statistic: 2.47
# p-value: 0.014

# %%
successes
# Out:
# [np.int64(53), np.int64(32)]

# %%
nobs
# Out:
# [333, 335]

# %% [markdown]
# Conclusions: Based on the results of the calculations we could tell that it makes sense to switch to the night shift. The p value is low (below 5%) and the diff between the variants is bigger than 5% points (referring to MEI).

# %% [markdown]
# Let's check it now for the dataset called `tips_too_small_diff.csv`:

# %%
tips = pd.read_csv('data/tips_too_small_diff.csv')

tips_night = tips[tips['version'] == 'night']
tips_day = tips[tips['version'] == 'day']

n_night = len(tips_night)
n_day = len(tips_day)
successes = [tips_night.conversion.sum(), tips_day.conversion.sum()]
nobs = [n_night, n_day]

z_stat, pval = proportions_ztest(successes, nobs=nobs)

print(f'conversion rate for day shift: {tips_day.conversion.sum()/n_day}')
print(f'conversion rate for night shift: {tips_night.conversion.sum()/n_night}')
print(f'z statistic: {z_stat:.2f}')
print(f'p-value: {pval:.3f}')
# Out:
# conversion rate for day shift: 0.12312312312312312
# conversion rate for night shift: 0.0955223880597015
# z statistic: -1.14
# p-value: 0.253

# %% [markdown]
# Conclusions:
#
# The diff between the two tests is too small to make a significant conclusion - the p value is high.

# %% [markdown]
# ## Comparing means
#
# In this scenario we imagine that in several days we worked both shifts and every day we computed how many tips we got on average. Below you can see how to compare the results of the test:

# %%
import scipy.stats as sps

tips = pd.read_csv('data/tips_means.csv')

tips_night = tips['night']
tips_day = tips['day']

test_statistic, pvalue = sps.ttest_ind(tips_day, tips_night)
print(f'average tips for day shift: {tips_day.mean()}')
print(f'average tips for night shift {tips_night.mean()}')
print (test_statistic, pvalue)
# Out:
# average tips for day shift: 2.6518728895668593
# average tips for night shift 3.0040922252482574
# -2.8205655591656953 0.006551683740313614

# %% [markdown]
# Conclusion: there is a significant difference between the two tests (small p value)

# %%
tips_night= tips[tips['version'] == 'night']

# %%
#loc:
tips_night.reset_index(drop=True, inplace=True)

for i in range(len(tips_night)):
    if tips_night.loc[i, "conversion"] != 0:
        print(f"index: {i}, conversion: {tips_night.loc[i, 'conversion']}")
# Out:
# index: 12, conversion: 1
# index: 25, conversion: 1
# index: 29, conversion: 1
# index: 35, conversion: 1
# index: 36, conversion: 1
# index: 42, conversion: 1
# index: 48, conversion: 1
# index: 51, conversion: 1
# index: 52, conversion: 1
# index: 56, conversion: 1
# index: 59, conversion: 1
# index: 83, conversion: 1
# index: 85, conversion: 1
# index: 86, conversion: 1
# index: 88, conversion: 1
# index: 91, conversion: 1
# index: 94, conversion: 1
# index: 96, conversion: 1
# index: 103, conversion: 1
# index: 106, conversion: 1
# index: 110, conversion: 1
# index: 120, conversion: 1
# index: 124, conversion: 1
# index: 127, conversion: 1
# index: 129, conversion: 1
# index: 132, conversion: 1
# index: 144, conversion: 1
# index: 148, conversion: 1
# index: 158, conversion: 1
# index: 166, conversion: 1
# index: 170, conversion: 1
# index: 172, conversion: 1
# index: 179, conversion: 1
# index: 190, conversion: 1
# index: 195, conversion: 1
# index: 197, conversion: 1
# index: 206, conversion: 1
# index: 217, conversion: 1
# index: 219, conversion: 1
# index: 243, conversion: 1
# index: 262, conversion: 1
# index: 269, conversion: 1
# index: 272, conversion: 1
# index: 279, conversion: 1
# index: 281, conversion: 1
# index: 282, conversion: 1
# index: 283, conversion: 1
# index: 284, conversion: 1
# index: 288, conversion: 1
# index: 305, conversion: 1
# index: 308, conversion: 1
# index: 322, conversion: 1
# index: 328, conversion: 1

# %%
#iloc:
tips_night.reset_index(drop=True, inplace=True)

for i in range(len(tips_night)):
    if tips_night.iloc[i]["conversion"] != 0:
        print(f"index: {i}, conversion: {tips_night.iloc[i]['conversion']}")
# Out:
# index: 12, conversion: 1
# index: 25, conversion: 1
# index: 29, conversion: 1
# index: 35, conversion: 1
# index: 36, conversion: 1
# index: 42, conversion: 1
# index: 48, conversion: 1
# index: 51, conversion: 1
# index: 52, conversion: 1
# index: 56, conversion: 1
# index: 59, conversion: 1
# index: 83, conversion: 1
# index: 85, conversion: 1
# index: 86, conversion: 1
# index: 88, conversion: 1
# index: 91, conversion: 1
# index: 94, conversion: 1
# index: 96, conversion: 1
# index: 103, conversion: 1
# index: 106, conversion: 1
# index: 110, conversion: 1
# index: 120, conversion: 1
# index: 124, conversion: 1
# index: 127, conversion: 1
# index: 129, conversion: 1
# index: 132, conversion: 1
# index: 144, conversion: 1
# index: 148, conversion: 1
# index: 158, conversion: 1
# index: 166, conversion: 1
# index: 170, conversion: 1
# index: 172, conversion: 1
# index: 179, conversion: 1
# index: 190, conversion: 1
# index: 195, conversion: 1
# index: 197, conversion: 1
# index: 206, conversion: 1
# index: 217, conversion: 1
# index: 219, conversion: 1
# index: 243, conversion: 1
# index: 262, conversion: 1
# index: 269, conversion: 1
# index: 272, conversion: 1
# index: 279, conversion: 1
# index: 281, conversion: 1
# index: 282, conversion: 1
# index: 283, conversion: 1
# index: 284, conversion: 1
# index: 288, conversion: 1
# index: 305, conversion: 1
# index: 308, conversion: 1
# index: 322, conversion: 1
# index: 328, conversion: 1

# %%
tips_night['conversion'].value_counts()
# Out:
# conversion
# 0    280
# 1     53
# Name: count, dtype: int64

# %%
tips_day = tips[tips['version'] == 'day']

# %%
#loc:
tips_day.reset_index(drop=True, inplace=True)

for i in range(len(tips_day)):
    if tips_day.loc[i, "conversion"] != 0:
        print(f"index: {i}, conversion: {tips_day.loc[i, 'conversion']}")
# Out:
# index: 9, conversion: 1
# index: 21, conversion: 1
# index: 41, conversion: 1
# index: 53, conversion: 1
# index: 58, conversion: 1
# index: 60, conversion: 1
# index: 66, conversion: 1
# index: 85, conversion: 1
# index: 89, conversion: 1
# index: 92, conversion: 1
# index: 99, conversion: 1
# index: 120, conversion: 1
# index: 125, conversion: 1
# index: 150, conversion: 1
# index: 151, conversion: 1
# index: 165, conversion: 1
# index: 169, conversion: 1
# index: 187, conversion: 1
# index: 206, conversion: 1
# index: 211, conversion: 1
# index: 213, conversion: 1
# index: 215, conversion: 1
# index: 217, conversion: 1
# index: 223, conversion: 1
# index: 240, conversion: 1
# index: 249, conversion: 1
# index: 250, conversion: 1
# index: 272, conversion: 1
# index: 275, conversion: 1
# index: 278, conversion: 1
# index: 295, conversion: 1
# index: 298, conversion: 1

# %%
#iloc:
tips_day.reset_index(drop=True, inplace=True)

for i in range(len(tips_day)):
    if tips_day.iloc[i]["conversion"] != 0:
        print(f"index: {i}, conversion: {tips_day.iloc[i]['conversion']}")
# Out:
# index: 9, conversion: 1
# index: 21, conversion: 1
# index: 41, conversion: 1
# index: 53, conversion: 1
# index: 58, conversion: 1
# index: 60, conversion: 1
# index: 66, conversion: 1
# index: 85, conversion: 1
# index: 89, conversion: 1
# index: 92, conversion: 1
# index: 99, conversion: 1
# index: 120, conversion: 1
# index: 125, conversion: 1
# index: 150, conversion: 1
# index: 151, conversion: 1
# index: 165, conversion: 1
# index: 169, conversion: 1
# index: 187, conversion: 1
# index: 206, conversion: 1
# index: 211, conversion: 1
# index: 213, conversion: 1
# index: 215, conversion: 1
# index: 217, conversion: 1
# index: 223, conversion: 1
# index: 240, conversion: 1
# index: 249, conversion: 1
# index: 250, conversion: 1
# index: 272, conversion: 1
# index: 275, conversion: 1
# index: 278, conversion: 1
# index: 295, conversion: 1
# index: 298, conversion: 1

# %%
tips_day['conversion'].value_counts()
# Out:
# conversion
# 0    303
# 1     32
# Name: count, dtype: int64
