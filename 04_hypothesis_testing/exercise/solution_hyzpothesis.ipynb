# %%
t_stat, p_value = stats.ttest_1samp(df['Order_Value'], popmean=75)

print(f"Sample Mean: {df['Order_Value'].mean():.2f}")
print(f"T-Statistic: {t_stat:.2f}")
print(f"P-Value: {p_value:.4f}")

# %% [markdown]
# Expected Output
#
# Sample Mean: 78.21
# T-Statistic: 2.79
# P-Value: 0.0081

# %%
mean = df['Order_Value'].mean()
std = df['Order_Value'].std # sample std
n = len(df['Order_Value'])

confidence = 0.95

ci_lower, ci_upper = stats.t.interval(confidence, df=n-1, loc=mean, scale=std/np.sqrt(n))
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# %% [markdown]
# Expected Output
#
# 95% Confidence Interval for mean: (76.20, 80.22)

# %% [markdown]
# Confidence Interval:
#
# We are 95% confident that the true average order value lies between $76.20 and $80.22.
#
# Hypothesis Test:
#
# Since the p-value (0.0081) is less than 0.05, we reject the null hypothesis.
# This means the true average order value is significantly different from $75.
#
# Business Implication:
#
# Customers are spending more than expected, which could indicate effective pricing or successful marketing strategies.
# The store may consider reviewing whether this higher spend can be sustained or optimized.
